# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])

print(np.sum(arr))   
print(np.prod(arr))    
print(np.min(arr))    
print(np.argmin(arr)) 
print(np.max(arr))     
print(np.argmax(arr))  
print(np.mean(arr))    
print(np.median(arr)) 
print(np.std(arr))     
print(np.var(arr))
# Out:
# 15
# 120
# 1
# 0
# 5
# 4
# 3.0
# 3.0
# 1.4142135623730951
# 2.0
